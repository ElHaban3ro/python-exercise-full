# %%
# Ejercicio 1
# Escribir un programa que pregunte al usuario su edad y muestre por pantalla si es mayor de edad o no.



age = int(input('Introduce tu edad ---------------->  '))

if age > 18:
  print('Puedes pasar.')
else:
  print('No tiene la edad necesaria para entrar a la plataforma')
# Out:
# Introduce tu edad ---------------->  53
# Puedes pasar.

# %%
# Ejercicio 2
# Escribir un programa que almacene la cadena de caracteres contraseña en una variable, 
# pregunte al usuario por la contraseña e imprima por pantalla si la contraseña 
# introducida por el usuario coincide con la guardada en la variable sin tener en 
# cuenta mayúsculas y minúsculas.


password = 'elpepe'
consult_password = input('\n\n\tIniciar Sesión\n\nContraseña:  ')


if consult_password == password:
  print('\n\n\t-------- Autorizado a la plataforma --------')
 
else:
  print('\n\n\t-------- ERROR; REVISA EL CORREO O CONTRASEÑA --------')
# Out:
# 	Iniciar Sesión
#
# Contraseña:  elpepe
#
#
# 	-------- Autorizado a la plataforma --------

# %%
# Ejercicio 3
# Escribir un programa que pida al usuario dos números y muestre por pantalla su división. 
# Si el divisor es cero el programa debe mostrar un error.


n1 = int(input('introduce el numero uno --------> '))
n2 = int(input('introduce el numero dos para dividir --------> '))



if n1 > 0 and n2 > 0:
  print(f'La división de {n1} / {n2} es \n\t>  {n1 / n2}')

else:
  print('\n\n\n\t--------------------- ERROR ---------------------')
# Out:
# introduce el numero uno --------> 0
# introduce el numero dos para dividir --------> 5
#
#
#
# 	--------------------- ERROR ---------------------

# %%
# Ejercicio 4
# Escribir un programa que pida al usuario un número entero y muestre por pantalla si es par o impar.


num = int(input('\n\t¿Mi Número es par?\n\nIngrese un numero ---------->  '))

if num % 2 == 0:
  print('\n\n\t> El número es par <')

else:
  print('\n\n\t> El número es impar <')
# Out:
# 	¿Mi Número es par?
#
# Ingrese un numero ---------->  ...
#
#
# 	> El número es par <

# %%
# Ejercicio 5
# Para tributar un determinado impuesto se debe ser mayor de 16 años y tener unos
# ingresos iguales o superiores a 1000 € mensuales. Escribir un programa que pregunte
# al usuario su edad y sus ingresos mensuales y muestre por pantalla si el usuario 
# tiene que tributar o no.


print('\t---------- Consulta para tributación del N34JSQ ----------')
nameT = input('\n\nIntroduzca su nombre ----- > ')
ageT = int(input('Introduzca su edad ----- > '))
ingresosT = float(input('Ingrese sus ingresos mensuales ----- > €'))

print(f'\n\nNombre: {nameT}\n\n> Edad: {ageT}\n\n> Ingresos: {ingresosT}')


if ingresosT >= 1000 and ageT > 16:
  print('\n\nUsted tiene el deber de tributar N34JSQ.')

else:
  print('\n\nNo debe tributar ningún impuesto!\n\nRecuerda que: \n\t> Para tener que tributar, tienes que tener más de 16 años y unos ingresos superiores a 1000€')
# Out:
# 	---------- Consulta para tributación del N34JSQ ----------
#
#
# Introduzca su nombre ----- > Fernando
# Introduzca su edad ----- > 20
# Ingrese sus ingresos mensuales ----- > €3
#
#
# Nombre: Fernando
#
# > Edad: 20
#
# > Ingresos: 3.0
#
#
# No debe tributar ningún impuesto!
#
# Recuerda que:
# 	> Para tener que tributar, tienes que tener más de 16 años y unos ingresos superiores a 1000€

# %%
# Ejercicio 6
# Los alumnos de un curso se han dividido en dos grupos A y B de acuerdo al sexo 
# y el nombre. El grupo A esta formado por las mujeres con un nombre anterior a 
# la M y los hombres con un nombre posterior a la N y el grupo B por el resto. Escribir 
# un programa que pregunte al usuario su nombre y sexo, y muestre por pantalla el 
# grupo que le corresponde.

print('\t---------------------- Asignación de grupos en la UNC ----------------------\n\n\n')
nameA = input('Introduzca su PRIMER NOMBRE y su PRIMER APELLIDO --------------> ').lower()
sexoA = input('Introduzca su sexo (M: mujer y H: hombre)  -----------> ').upper()
inicial = nameA[0:1]



if inicial >= 'a' and inicial <= 'm' and sexoA == 'M':
  print('\n\n\t> Usted pertenece al grupo A. Comuniquese con su respectivo profesor')
  print('\n -------------------------Grupo asignado: A ------------------------- ')


elif inicial >= 'n' and inicial <= 'z' and sexoA == 'H':
  print('\n\n\t> Usted pertenece al grupo A. Comuniquese con su respectivo profesor')
  print('\n -------------------------Grupo asignado: A ------------------------- ')

  
else:
  print('\n\n\t> Usted pertenece al grupo B. Comuniquese con su respectivo profesor')
  print('\n -------------------------Grupo asignado: B ------------------------- ')
# Out:
# 	---------------------- Asignación de grupos en la UNC ----------------------
#
#
#
# Introduzca su PRIMER NOMBRE y su PRIMER APELLIDO --------------> Fer
# Introduzca su sexo (M: mujer y H: hombre)  -----------> h
# H
#
#
# 	> Usted pertenece al grupo B. Comuniquese con su respectivo profesor
#
#  -------------------------Grupo asignado: B -------------------------

# %% [markdown]
# ---
#
#
# Los tramos impositivos para la declaración de la renta en un determinado país son los siguientes:
#
# |         Renta          | Tipo impositivo |
# | :--------------------: | :-------------: |
# |    Menos de 10000€     |       5%        |
# | Entre 10000€ y 20000€  |       15%       |
# | Entre 20000€ y 35000€  |       20%       |
# | Entre 35000€ y 60000€  |       30%       |
# |     Más de 60000€      |       45%       |

# %%
# Ejercicio 7
# Escribir un programa que pregunte al usuario su renta anual y muestre por pantalla el tipo impositivo que le corresponde. (la tabla de renta
#  y cantidad de impositivo está en la web de donde estoy haciendo los ejercicios)


print('\t--------------- ¡Calcule su tipo de impositivo ---------------\n\n\n')
renta_anual = float(input('Introduzca su cantidad de renta anual -------------->  €'))




if renta_anual > 0 and renta_anual < 10000:
  print(f'\n\n\t> Ya que su renta anual es de {renta_anual}€, le corresponde un impositivo de {(renta_anual * 5) / 100}€ ')


elif renta_anual >= 10000 and renta_anual < 20000:
  print(f'\n\n\t> Ya que su renta anual es de {renta_anual}€, le corresponde un impositivo de {(renta_anual * 15) / 100}€ ')


elif renta_anual >= 20000 and renta_anual < 35000:
  print(f'\n\n\t> Ya que su renta anual es de {renta_anual}€, le corresponde un impositivo de {(renta_anual * 20) / 100}€ ')


elif renta_anual >= 35000 and renta_anual < 60000:
  print(f'\n\n\t> Ya que su renta anual es de {renta_anual}€, le corresponde un impositivo de {(renta_anual * 30) / 100}€')


elif renta_anual >= 60000:
  print(f'\n\n\t> Ya que su renta anual es de {renta_anual}€, le corresponde un impositivo de {(renta_anual * 45) / 100}€ ')


else:
  print(f'\n\n\t>> ---------------- Algo ha sucedido. Usted ha ingresado {renta_anual}€ de renta anual, asegurese de que esto sea correcto!')
# Out:
# 	--------------- ¡Calcule su tipo de impositivo ---------------
#
#
#
# Introduzca su cantidad de renta anual -------------->  €500000
#
#
# 	> Ya que su renta anual es de 500000.0€, le corresponde un impositivo de 225000.0€

# %%
# Ejercicio 8
# En una determinada empresa, sus empleados son evaluados al final de cada año. 
# Los puntos que pueden obtener en la evaluación comienzan en 0.0 y pueden ir aumentando, 
# traduciéndose en mejores beneficios. Los puntos que pueden conseguir los empleados 
# pueden ser 0.0, 0.4, 0.6 o más, pero no valores intermedios entre las cifras 
# mencionadas. A continuación se muestra una tabla con los niveles correspondientes 
# a cada puntuación. La cantidad de dinero conseguida en cada nivel es de 2.400€ 
# multiplicada por la puntuación del nivel.


# Escribir un programa que lea la puntuación del usuario e indique su nivel de 
# rendimiento, así como la cantidad de dinero que recibirá el usuario.


points = float(input('Ingrese su puntuación ----------->  '))

if points == 0.0:
  print('\n\n\t> Lo sentimos, su puntuación es 0.0 :(, no podemos pagarle nada...')

elif points == 0.4:
  print(f'\n\n\t> Hola, su puntuación es de 0.4, el pago es de {2400 * 0.4}')

elif points >= 0.6:
  print(f'\n\n\t> enhorabuena!, su puntuación es de {points}, el pago es de {2400 * points}')

else:
  print('\n\n\t> Lo sentimos, ha habido un error. Recuerde! nosotros solo evaluamos como 0.0, 0.4 y 0.6 o más.')
# Out:
# Ingrese su puntuación ----------->  .1
#
#
# 	> Lo sentimos, ha habido un error. Recuerde! nosotros solo evaluamos como 0.0, 0.4 y 0.6 o más.

# %%
# Ejercicio 9
# Escribir un programa para una empresa que tiene salas de juegos para todas las 
# edades y quiere calcular de forma automática el precio que debe cobrar a sus 
# clientes por entrar. El programa debe preguntar al usuario la edad del cliente y 
# mostrar el precio de la entrada. Si el cliente es menor de 4 años puede entrar 
# gratis, si tiene entre 4 y 18 años debe pagar 5€ y si es mayor de 18 años, 10€.



edadJ = int(input('Ingrese su edad ------------> '))

if edadJ < 4 and edadJ > 0:
  print('\n\n\t> No debe pagar nada! es completamente gratis.')

elif edadJ > 4 and edadJ < 18:
  print('\n\n\t> Para ingresar, su pago tiene que ser de 5€!')

elif edadJ > 18:
  print('\n\n\t> Para ingresar, su pago tiene que ser de 10€!')

else:
  print('\n\n\t> Pará master en el humor, asegurese de que esté ingresando una edad real.')
# Out:
# Ingrese su edad ------------> 16
#
#
# 	> Para ingresar, su pago tiene que ser de 5€!

# %%
# Ejercicio 10
# La pizzería Bella Napoli ofrece pizzas vegetarianas y no vegetarianas a sus clientes. 
# Los ingredientes para cada tipo de pizza aparecen a continuación.

# Ingredientes vegetarianos: Pimiento y tofu.
# Ingredientes no vegetarianos: Peperoni, Jamón y Salmón.

# Escribir un programa que pregunte al usuario si quiere una pizza vegetariana o no, 
# y en función de su respuesta le muestre un menú con los ingredientes disponibles 
# para que elija. Solo se puede eligir un ingrediente además de la mozzarella y 
# el tomate que están en todas la pizzas. Al final se debe mostrar por pantalla 
# si la pizza elegida es vegetariana o no y todos los ingredientes que lleva.


print('\t--------------------------- Bienvenid@ a La pizzería Bella Napoli ---------------------------\n\n')

pizza = int(input('¿Qué pizza quiere? Marque\n\t> (1) Vegetariana\n\t> (2) No Vegetariana\n\n----------> '))
print('\n¡Recuerde! TODAS las PIZZAS traen Mozzarella y Tomate.\n\n\n\n')

if pizza == 1:
  print(f'\n\nUsted quiere pizza vegetariana. Por favor elija el otro ingrediente(solo puede elejir uno)\n\t> (1) Pimiento\n\t> (2) Tofu')
  ingredientes = int(input('Quiero... > '))
  

  if ingredientes == 1:
    print(f'\n\n\n\t> ¡Ha llegado la pizza vegetariana! \n\tLos ingredientes son: \n\t\t- Tomate\n\t\t- Mozzarella\n\t\t- Pimiento')

  elif ingredientes == 2:
    print(f'\n\n\n\t> ¡Ha llegado la pizza vegetariana! \n\tLos ingredientes son: \n\t\t- Tomate\n\t\t- Mozzarella\n\t\t- Tofu')

  else:
    print('\n\n\t-- ERROR, ASEGURESE A LA PROXIMA DE ELEGIR UN INGREDIENTE CORRECTO --')




elif pizza == 2:
  print(f'\n\nUsted quiere pizza NO vegetariana. Por favor elija el otro ingrediente(solo puede elejir otro uno)\n\t> (1) Peperoni\n\t> (2) Jamón\n\t> (3) Salmón')
  ingredientes = int(input('Quiero... > '))


  if ingredientes == 1:
    print(f'\n\n\n\t> ¡Ha llegado la pizza NO vegetariana! \n\tLos ingredientes son: \n\t\t- Tomate\n\t\t- Mozzarella\n\t\t- Peperoni')

  elif ingredientes == 2:
    print(f'\n\n\n\t> ¡Ha llegado la pizza NO vegetariana! \n\tLos ingredientes son: \n\t\t- Tomate\n\t\t- Mozzarella\n\t\t- Jamón')

  elif ingredientes == 3:
    print(f'\n\n\n\t> ¡Ha llegado la pizza NO vegetariana! \n\tLos ingredientes son: \n\t\t- Tomate\n\t\t- Mozzarella\n\t\t- Salmón')

  else:
    print('\n\n\t-- ERROR, ASEGURESE A LA PROXIMA DE ELEGIR UN INGREDIENTE CORRECTO --')
# Out:
# 	--------------------------- Bienvenid@ a La pizzería Bella Napoli ---------------------------
#
#
# ¿Qué pizza quiere? Marque
# 	> (1) Vegetariana
# 	> (2) No Vegetariana
#
# ----------> 2
#
# ¡Recuerde! TODAS las PIZZAS traen Mozzarella y Tomate.
#
#
#
#
#
#
# Usted quiere pizza NO vegetariana. Por favor elija el otro ingrediente(solo puede elejir otro uno)
# 	> (1) Peperoni
# 	> (2) Jamón
# 	> (3) Salmón
# Quiero... > 3
#
#
#
# 	> ¡Ha llegado la pizza NO vegetariana!
# 	Los ingredientes son:
# 		- Tomate
# 		- Mozzarella
# 		- Salmón
